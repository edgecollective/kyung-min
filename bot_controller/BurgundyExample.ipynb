# %% [markdown]
# # Burgundy Board Example
#
# (Press Shift+Enter to send commands)

# %% [markdown]
# ## Initial Step: Connecting to the Board

# %%
# !ls /dev/ttyAC*
# Out:
# /dev/ttyACM0

# %%
from bot_controller import Core, Direction, DigitalState
import time

# %%
ctrl = Core('/dev/ttyACM0')

# %% [markdown]
# ## Controlling LEDs

# %%
# assign leds to pin numbers
Blue_LED=22
Green_LED=23
Red_LED=24

# %%
# turn the Blue LED on
ctrl.digital(Blue_LED, state=DigitalState.on)
# Out:
# True

# %%
# turn the Blue LED off
ctrl.digital(Blue_LED, state=DigitalState.off)
# Out:
# True

# %%
# Blink an LED three times
for i in range(0,3):
    ctrl.digital(Blue_LED, state=DigitalState.on)
    time.sleep(.3)
    ctrl.digital(Blue_LED, state=DigitalState.off)
    time.sleep(.3)

# %% [markdown]
# ## Controlling a Servo

# %%
ctrl.servo(1, 180)
# Out:
# True

# %%
ctrl.servo(2, 180)
# Out:
# True

# %% [markdown]
# ## Controlling a Stepper

# %%
ctrl.stepper(1, 50, speed=100)

# %%
ctrl.stepper(2, 100, speed=100)

# %%
ctrl.external_stepper(1, 100, speed=100)

# %% [markdown]
# ## Measuring and Plotting Temperature

# %%
def temp_reading(x):
    temp = ctrl.get_temp()
    print(temp)
    return temp

tempvals=[]

for i in range(0,10):
    t=ctrl.get_temp()
    print(t)
    tempvals.append(t)
    time.sleep(2)
    
print(tempvals)
# Out:
# [21.72, 21.75, 21.75, 21.84, 21.91, 21.91, 21.97, 21.97, 22.0, 22.0]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.plot(tempvals)

# %% [markdown]
# ## Image Capture

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
cap=cv2.VideoCapture(0)
ret,frame=cap.read()
plt.imshow(frame)
plt.show()

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()
